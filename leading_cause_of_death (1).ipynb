# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
pd.set_option('display.max_columns', None) #this code allows for all columns to be displayed

# %% [markdown]
# The structure of the data is rectangular as it represents row and columns.

# %% [markdown]
# For The granularity,  each data point represents a single cause of death per gender of each race/ethnicity data therefore it has coarse level of granularity.

# %% [markdown]
# Since I am interested in the causes of death in New York City, this datset covers the right amount of information.

# %% [markdown]
# The data is from 2007 to 2021. Therefore the temporality is each year from 2007 to 2021.

# %% [markdown]
# There are some faithfulness problems because there is missing data.

# %%
causes = pd.read_csv("https://raw.githubusercontent.com/mducasse714/mat301-datasets/refs/heads/main/New_York_City_Leading_Causes_of_Death_20260223.csv", na_values = ["."])
causes.head(20)
# Out:
#     Year                                      Leading Cause     Sex  \
# 0   2021  Mental and Behavioral Disorders due to Acciden...    Male
# 1   2021                                   All Other Causes  Female
# 2   2021               Chronic Liver Diseases and Cirrhosis    Male
# 3   2021     Diseases of Heart (I00-I09, I11, I13, I20-I51)  Female
# 4   2021            Influenza (Flu) and Pneumonia (J09-J18)    Male
# 5   2021            Influenza (Flu) and Pneumonia (J09-J18)  Female
# 6   2021              Malignant Neoplasms (Cancer: C00-C97)  Female
# 7   2021                                           Covid-19  Female
# 8   2021          Cerebrovascular Disease (Stroke: I60-I69)  Female
# 9   2021     Diseases of Heart (I00-I09, I11, I13, I20-I51)  Female
# 10  2021                                   All Other Causes  Female
# 11  2021  Mental and Behavioral Disorders due to Acciden...  Female
# 12  2021                          Alzheimer's Disease (G30)  Female
# 13  2021                        Diabetes Mellitus (E10-E14)  Female
# 14  2021                        Diabetes Mellitus (E10-E14)  Female
# 15  2021            Influenza (Flu) and Pneumonia (J09-J18)  Female
# 16  2021       Chronic Lower Respiratory Diseases (J40-J47)  Female
# 17  2021          Cerebrovascular Disease (Stroke: I60-I69)    Male
# 18  2021  Essential Hypertension and Renal Diseases (I10...  Female
# 19  2021                                   All Other Causes  Female
#
#            Race Ethnicity  Deaths  Death Rate  Age Adjusted Death Rate
# 0   Other Race/ Ethnicity     9.0         NaN                      NaN
# 1      Not Stated/Unknown   102.0         NaN                      NaN
# 2      Not Stated/Unknown    16.0         NaN                      NaN
# 3                Hispanic  1409.0       111.0                     95.5
# 4      Not Stated/Unknown    16.0         NaN                      NaN
# 5   Other Race/ Ethnicity     4.0         NaN                      NaN
# 6                Hispanic  1157.0        91.2                     80.8
# 7                Hispanic   966.0        76.1                     66.8
# 8                Hispanic   265.0        20.9                     18.0
# 9      Not Stated/Unknown   113.0         NaN                      NaN
# 10  Other Race/ Ethnicity    71.0         NaN                      NaN
# 11               Hispanic   233.0        18.4                     17.8
# 12               Hispanic   223.0        17.6                     14.7
# 13               Hispanic   184.0        14.5                     12.6
# 14     Not Stated/Unknown     7.0         NaN                      NaN
# 15               Hispanic   169.0        13.3                     11.6
# 16               Hispanic   163.0        12.8                     11.3
# 17     Not Stated/Unknown    16.0         NaN                      NaN
# 18               Hispanic   147.0        11.6                      9.9
# 19               Hispanic  1589.0       125.2                    111.0

# %%
causes['Year'].unique()
# Out:
# array([2021, 2020, 2019, 2018, 2017, 2016, 2015, 2014, 2013, 2012, 2011,
#        2010, 2009, 2008, 2007])

# %%
causes.columns
# Out:
# Index(['Year', 'Leading Cause', 'Sex', 'Race Ethnicity', 'Deaths',
#        'Death Rate', 'Age Adjusted Death Rate'],
#       dtype='object')

# %% [markdown]
# #Cleaning data

# %% [markdown]
# removing duplicates,missing rows, Changing the text in columns

# %%
dup_filter = causes.duplicated() # 2 duplicated rows and removed them
causes[dup_filter]
# Out:
#      Year                                      Leading Cause     Sex  \
# 314  2019                          Alzheimer's Disease (G30)  Female
# 382  2019  Mental and Behavioral Disorders due to Acciden...    Male
#
#             Race Ethnicity  Deaths  Death Rate  Age Adjusted Death Rate
# 314  Other Race/ Ethnicity     3.0         NaN                      NaN
# 382  Other Race/ Ethnicity     5.0         NaN                      NaN

# %%
causes = causes.drop_duplicates()
causes
# Out:
#       Year                                      Leading Cause     Sex  \
# 0     2021  Mental and Behavioral Disorders due to Acciden...    Male
# 1     2021                                   All Other Causes  Female
# 2     2021               Chronic Liver Diseases and Cirrhosis    Male
# 3     2021     Diseases of Heart (I00-I09, I11, I13, I20-I51)  Female
# 4     2021            Influenza (Flu) and Pneumonia (J09-J18)    Male
# ...    ...                                                ...     ...
# 2097  2007                        Diabetes Mellitus (E10-E14)       F
# 2098  2007            Influenza (Flu) and Pneumonia (J09-J18)       F
# 2099  2007            Influenza (Flu) and Pneumonia (J09-J18)       F
# 2100  2007          Cerebrovascular Disease (Stroke: I60-I69)       M
# 2101  2007  Mental and Behavioral Disorders due to Use of ...       M
#
#              Race Ethnicity  Deaths  Death Rate  Age Adjusted Death Rate
# 0     Other Race/ Ethnicity     9.0         NaN                      NaN
# 1        Not Stated/Unknown   102.0         NaN                      NaN
# 2        Not Stated/Unknown    16.0         NaN                      NaN
# 3                  Hispanic  1409.0       111.0                     95.5
# 4        Not Stated/Unknown    16.0         NaN                      NaN
# ...                     ...     ...         ...                      ...
# 2097     White Non-Hispanic   231.0        16.1                      9.8
# 2098     White Non-Hispanic   659.0        45.9                     23.2
# 2099     Not Stated/Unknown     NaN         NaN                      NaN
# 2100               Hispanic   126.0        11.6                     20.0
# 2101     Not Stated/Unknown     NaN         NaN                      NaN
#
# [2100 rows x 7 columns]

# %%
len(causes)
# Out:
# 2100

# %%
causes.describe()
# Out:
#               Year       Deaths   Death Rate  Age Adjusted Death Rate
# count  2100.000000  1962.000000  1373.000000              1373.000000
# mean   2014.084762   429.689602    56.258163                53.607305
# std       4.333133   827.894141    75.598398                68.109884
# min    2007.000000     1.000000     2.400000                 2.500000
# 25%    2010.000000    25.000000    12.843000                12.338107
# 50%    2014.000000   141.000000    20.100000                19.800000
# 75%    2018.000000   317.750000    78.900000                81.500000
# max    2021.000000  7050.000000   491.400000               414.594473

# %%
causes.describe(include = ["O"])
# Out:
#            Leading Cause   Sex         Race Ethnicity
# count               2100  2100                   2100
# unique                42     4                      8
# top     All Other Causes     F  Other Race/ Ethnicity
# freq                 182   622                    411

# %%
causes.isnull().sum()
# Out:
# Year                         0
# Leading Cause                0
# Sex                          0
# Race Ethnicity               0
# Deaths                     138
# Death Rate                 727
# Age Adjusted Death Rate    727
# dtype: int64

# %%
causes_cleaned = causes.dropna()
causes_cleaned
# Out:
#       Year                                      Leading Cause     Sex  \
# 3     2021     Diseases of Heart (I00-I09, I11, I13, I20-I51)  Female
# 6     2021              Malignant Neoplasms (Cancer: C00-C97)  Female
# 7     2021                                           Covid-19  Female
# 8     2021          Cerebrovascular Disease (Stroke: I60-I69)  Female
# 11    2021  Mental and Behavioral Disorders due to Acciden...  Female
# ...    ...                                                ...     ...
# 2095  2007  Human Immunodeficiency Virus Disease (HIV: B20...       M
# 2096  2007  Essential Hypertension and Renal Diseases (I10...       F
# 2097  2007                        Diabetes Mellitus (E10-E14)       F
# 2098  2007            Influenza (Flu) and Pneumonia (J09-J18)       F
# 2100  2007          Cerebrovascular Disease (Stroke: I60-I69)       M
#
#           Race Ethnicity  Deaths  Death Rate  Age Adjusted Death Rate
# 3               Hispanic  1409.0       111.0                     95.5
# 6               Hispanic  1157.0        91.2                     80.8
# 7               Hispanic   966.0        76.1                     66.8
# 8               Hispanic   265.0        20.9                     18.0
# 11              Hispanic   233.0        18.4                     17.8
# ...                  ...     ...         ...                      ...
# 2095  Black Non-Hispanic   377.0        44.2                     44.2
# 2096  Black Non-Hispanic   166.0        15.8                     15.0
# 2097  White Non-Hispanic   231.0        16.1                      9.8
# 2098  White Non-Hispanic   659.0        45.9                     23.2
# 2100            Hispanic   126.0        11.6                     20.0
#
# [1373 rows x 7 columns]

# %%
causes_cleaned.dtypes
# Out:
# Year                         int64
# Leading Cause               object
# Sex                         object
# Race Ethnicity              object
# Deaths                     float64
# Death Rate                 float64
# Age Adjusted Death Rate    float64
# dtype: object

# %%
causes_cleaned.describe() #numerical data types
# Out:
#               Year       Deaths   Death Rate  Age Adjusted Death Rate
# count  1373.000000  1373.000000  1373.000000              1373.000000
# mean   2014.139111   602.957757    56.258163                53.607305
# std       4.332098   937.479492    75.598398                68.109884
# min    2007.000000     5.000000     2.400000                 2.500000
# 25%    2010.000000   110.000000    12.843000                12.338107
# 50%    2014.000000   220.000000    20.100000                19.800000
# 75%    2018.000000   529.000000    78.900000                81.500000
# max    2021.000000  7050.000000   491.400000               414.594473

# %%
causes_cleaned.describe(include = ["O"]) #for nonintegers or non-numbers
# Out:
#                                          Leading Cause   Sex  \
# count                                             1373  1373
# unique                                              28     4
# top     Diseases of Heart (I00-I09, I11, I13, I20-I51)     M
# freq                                               124   412
#
#                     Race Ethnicity
# count                         1373
# unique                           7
# top     Asian and Pacific Islander
# freq                           333

# %%
causes_cleaned['Sex'].unique()
# Out:
# array(['Female', 'Male', 'F', 'M'], dtype=object)

# %%
gender_map = {"M":"Male", "F":"Female", "Male":"Male", "Female":"Female"} #dictionary doing a few change
causes_cleaned["Sex"] = causes_cleaned["Sex"].map(gender_map)
causes_cleaned
causes_cleaned["Sex"] = causes_cleaned["Sex"].map(gender_map)
causes_cleaned
# Out:
# /tmp/ipykernel_168/3086009923.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   causes_cleaned["Sex"] = causes_cleaned["Sex"].map(gender_map)
# /tmp/ipykernel_168/3086009923.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   causes_cleaned["Sex"] = causes_cleaned["Sex"].map(gender_map)
#       Year                                      Leading Cause     Sex  \
# 3     2021     Diseases of Heart (I00-I09, I11, I13, I20-I51)  Female
# 6     2021              Malignant Neoplasms (Cancer: C00-C97)  Female
# 7     2021                                           Covid-19  Female
# 8     2021          Cerebrovascular Disease (Stroke: I60-I69)  Female
# 11    2021  Mental and Behavioral Disorders due to Acciden...  Female
# ...    ...                                                ...     ...
# 2095  2007  Human Immunodeficiency Virus Disease (HIV: B20...    Male
# 2096  2007  Essential Hypertension and Renal Diseases (I10...  Female
# 2097  2007                        Diabetes Mellitus (E10-E14)  Female
# 2098  2007            Influenza (Flu) and Pneumonia (J09-J18)  Female
# 2100  2007          Cerebrovascular Disease (Stroke: I60-I69)    Male
#
#           Race Ethnicity  Deaths  Death Rate  Age Adjusted Death Rate
# 3               Hispanic  1409.0       111.0                     95.5
# 6               Hispanic  1157.0        91.2                     80.8
# 7               Hispanic   966.0        76.1                     66.8
# 8               Hispanic   265.0        20.9                     18.0
# 11              Hispanic   233.0        18.4                     17.8
# ...                  ...     ...         ...                      ...
# 2095  Black Non-Hispanic   377.0        44.2                     44.2
# 2096  Black Non-Hispanic   166.0        15.8                     15.0
# 2097  White Non-Hispanic   231.0        16.1                      9.8
# 2098  White Non-Hispanic   659.0        45.9                     23.2
# 2100            Hispanic   126.0        11.6                     20.0
#
# [1373 rows x 7 columns]

# %%
#causes_cleaned["Deaths"] = causes_cleaned["Deaths"].astype(float)
#causes_cleaned["Death Rate", "Age Adjusted Death Rate"] = causes_cleaned["Death Rate", "Age Adjusted Death Rate"].astype(float)

# %% [markdown]
# # Single variable distribution plots

# %%
#What is the trend of Age Adjusted Death Rate during this time period?
sns.relplot(x = "Year", y = "Age Adjusted Death Rate", kind = "line", data = causes_cleaned)
plt.title("Age Adjusted Death Rate from 2007 - 2021")
plt.xlabel("Year")
plt.ylabel("Age Adjusted Death Rate")
plt.show()

# %%
#histogram for Age Adjusted Death Rate
causes_cleaned['Age Adjusted Death Rate'].hist(bins = 10)
plt.title("Histogram of Age Adjusted Death Rate")
plt.xlabel("Age Adjusted Death Rate")
plt.ylabel("Frequency")
plt.show()

# %%
causes_cleaned['Death Rate'].hist(bins = 20)
plt.title("Histogram of Death Rate")
plt.xlabel("Death Rate")
plt.ylabel("Frequency")
plt.show()

# %%
#WHAT IS THE MAJOR CAUSE OF DEATH AMONG HISPANIC FEMALES
hispanic = causes_cleaned["Race Ethnicity"] == "Hispanic"
female = causes_cleaned["Sex"] == "Female"
hispanic_f = causes_cleaned[hispanic & female]
hispanic_f
# Out:
#       Year                                      Leading Cause     Sex  \
# 3     2021     Diseases of Heart (I00-I09, I11, I13, I20-I51)  Female
# 6     2021              Malignant Neoplasms (Cancer: C00-C97)  Female
# 7     2021                                           Covid-19  Female
# 8     2021          Cerebrovascular Disease (Stroke: I60-I69)  Female
# 11    2021  Mental and Behavioral Disorders due to Acciden...  Female
# ...    ...                                                ...     ...
# 2078  2007                                   All Other Causes  Female
# 2081  2007          Cerebrovascular Disease (Stroke: I60-I69)  Female
# 2082  2007  Essential Hypertension and Renal Diseases (I10...  Female
# 2085  2007                        Diabetes Mellitus (E10-E14)  Female
# 2091  2007                               Septicemia (A40-A41)  Female
#
#      Race Ethnicity  Deaths  Death Rate  Age Adjusted Death Rate
# 3          Hispanic  1409.0       111.0                     95.5
# 6          Hispanic  1157.0        91.2                     80.8
# 7          Hispanic   966.0        76.1                     66.8
# 8          Hispanic   265.0        20.9                     18.0
# 11         Hispanic   233.0        18.4                     17.8
# ...             ...     ...         ...                      ...
# 2078       Hispanic   820.0        70.2                     85.6
# 2081       Hispanic   164.0        14.0                     18.3
# 2082       Hispanic    78.0         6.7                      8.9
# 2085       Hispanic   205.0        17.6                     22.6
# 2091       Hispanic    49.0         4.2                      5.5
#
# [166 rows x 7 columns]

# %%
#how many hispanic women died due to Diseases of Heart (I00-I09, I11, I13, I20-I51) during this period
heart_disease = hispanic_f["Leading Cause"] == "Diseases of Heart (I00-I09, I11, I13, I20-I51)"
hispanic_heart_disease = hispanic_f[heart_disease]
hispanic_heart_disease
# Out:
#       Year                                   Leading Cause     Sex  \
# 3     2021  Diseases of Heart (I00-I09, I11, I13, I20-I51)  Female
# 202   2020  Diseases of Heart (I00-I09, I11, I13, I20-I51)  Female
# 402   2019  Diseases of Heart (I00-I09, I11, I13, I20-I51)  Female
# 539   2018  Diseases of Heart (I00-I09, I11, I13, I20-I51)  Female
# 710   2017  Diseases of Heart (I00-I09, I11, I13, I20-I51)  Female
# 826   2016  Diseases of Heart (I00-I09, I11, I13, I20-I51)  Female
# 879   2015  Diseases of Heart (I00-I09, I11, I13, I20-I51)  Female
# 1025  2014  Diseases of Heart (I00-I09, I11, I13, I20-I51)  Female
# 1226  2013  Diseases of Heart (I00-I09, I11, I13, I20-I51)  Female
# 1346  2012  Diseases of Heart (I00-I09, I11, I13, I20-I51)  Female
# 1464  2011  Diseases of Heart (I00-I09, I11, I13, I20-I51)  Female
# 1618  2010  Diseases of Heart (I00-I09, I11, I13, I20-I51)  Female
# 1765  2009  Diseases of Heart (I00-I09, I11, I13, I20-I51)  Female
# 1933  2008  Diseases of Heart (I00-I09, I11, I13, I20-I51)  Female
# 2004  2007  Diseases of Heart (I00-I09, I11, I13, I20-I51)  Female
#
#      Race Ethnicity  Deaths  Death Rate  Age Adjusted Death Rate
# 3          Hispanic  1409.0  111.000000                95.500000
# 202        Hispanic  1850.0  142.200000               127.600000
# 402        Hispanic  1574.0  125.735722               111.735337
# 539        Hispanic  1493.0  118.033000               109.083000
# 710        Hispanic  1437.0  110.817637               106.281597
# 826        Hispanic  1485.0  115.897012               120.315311
# 879        Hispanic  1361.0  106.484024               113.376700
# 1025       Hispanic  1230.0   97.100000               106.700000
# 1226       Hispanic  1261.0  101.000000               113.600000
# 1346       Hispanic  1263.0  102.000000               118.400000
# 1464       Hispanic  1348.0  110.000000               131.800000
# 1618       Hispanic  1316.0  108.100000               133.200000
# 1765       Hispanic  1349.0  112.700000               143.800000
# 1933       Hispanic  1445.0  122.300000               160.700000
# 2004       Hispanic  1418.0  121.500000               164.300000

# %%
sns.relplot(x = "Year", y = "Deaths", kind = "line", data = hispanic_heart_disease)
plt.title("Hispanic Women that died due to Heart Diseases from 2007 - 2021")
plt.xlabel("Year")
plt.ylabel("Deaths")
plt.show()
#What year did hispanic females have death amout due to heart diseases
#During 2020 women had the highest deaths related to heart diseases.  1,856 died in 2020 of heart diseases.

# %% [markdown]
# #  Multiple variable plots

# %%
causes_cleaned
# Out:
#       Year                                      Leading Cause     Sex  \
# 3     2021     Diseases of Heart (I00-I09, I11, I13, I20-I51)  Female
# 6     2021              Malignant Neoplasms (Cancer: C00-C97)  Female
# 7     2021                                           Covid-19  Female
# 8     2021          Cerebrovascular Disease (Stroke: I60-I69)  Female
# 11    2021  Mental and Behavioral Disorders due to Acciden...  Female
# ...    ...                                                ...     ...
# 2095  2007  Human Immunodeficiency Virus Disease (HIV: B20...    Male
# 2096  2007  Essential Hypertension and Renal Diseases (I10...  Female
# 2097  2007                        Diabetes Mellitus (E10-E14)  Female
# 2098  2007            Influenza (Flu) and Pneumonia (J09-J18)  Female
# 2100  2007          Cerebrovascular Disease (Stroke: I60-I69)    Male
#
#           Race Ethnicity  Deaths  Death Rate  Age Adjusted Death Rate
# 3               Hispanic  1409.0       111.0                     95.5
# 6               Hispanic  1157.0        91.2                     80.8
# 7               Hispanic   966.0        76.1                     66.8
# 8               Hispanic   265.0        20.9                     18.0
# 11              Hispanic   233.0        18.4                     17.8
# ...                  ...     ...         ...                      ...
# 2095  Black Non-Hispanic   377.0        44.2                     44.2
# 2096  Black Non-Hispanic   166.0        15.8                     15.0
# 2097  White Non-Hispanic   231.0        16.1                      9.8
# 2098  White Non-Hispanic   659.0        45.9                     23.2
# 2100            Hispanic   126.0        11.6                     20.0
#
# [1373 rows x 7 columns]

# %%
gender_year_death = causes_cleaned.groupby(["Year","Sex"])["Deaths"].sum().unstack()
gender_year_death.plot(kind = 'bar', figsize=(14,8))
plt.title("Deaths by Gender from 2007 to 2021")
plt.xlabel("Year")
plt.ylabel("Deaths")
plt.xticks(rotation = 45)
plt.show()
#What years saw the most death between males and females

# %%
gender_year_death
# Out:
# Sex    Female     Male
# Year
# 2007  27493.0  25903.0
# 2008  27505.0  25932.0
# 2009  26659.0  25539.0
# 2010  26414.0  25510.0
# 2011  26853.0  25338.0
# 2012  26417.0  25217.0
# 2013  26609.0  25516.0
# 2014  26420.0  25435.0
# 2015  27011.0  25995.0
# 2016  26695.0  26407.0
# 2017  26709.0  26478.0
# 2018  27516.0  27154.0
# 2019  26645.0  27415.0
# 2020  37486.0  41899.0
# 2021  29862.0  31829.0

# %%
sns.scatterplot(x='Deaths', y='Death Rate', data=causes_cleaned)
plt.xlabel('Deaths')
plt.ylabel('Death Rate')
plt.title('Deaths vs. Death Rate')
plt.show()
